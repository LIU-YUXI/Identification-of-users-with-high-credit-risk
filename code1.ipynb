# %%
# 数据处理
import pandas as pd
import numpy as np
 
# 绘图
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"D:\2021\rc\test_without_label\test_base.csv", encoding='gbk', index_col=0)

# %%
print(df)
# Out:
#                    sex    age    provider       level    verified  using_time  \
# user
# Test_02230  category 0  24914  category 0  category 2  category 0       24735
# Test_21691  category 0  24920  category 0  category 2  category 0       24725
# Test_31857  category 1  24877  category 2  category 2  category 0       24722
# Test_13647  category 0  24914  category 0  category 2  category 0       24733
# Test_44427  category 0  24895  category 0  category 2  category 0       24713
# ...                ...    ...         ...         ...         ...         ...
# Test_27066  category 0  24938  category 2  category 1  category 0       24707
# Test_27848  category 0  24986  category 0  category 2  category 0       24737
# Test_24860  category 0  24920  category 0  category 1  category 0       24717
# Test_10406  category 0  24956  category 2  category 1  category 0       24707
# Test_29649  category 0  24840  category 0  category 2  category 0       24732
#
# ...

# %%
df.loc[df.sex=="category 0",'sex0']=1
df.loc[df.sex!="category 0",'sex0']=0
df.loc[df.sex=="category 1",'sex1']=1
df.loc[df.sex!="category 1",'sex1']=0
df.drop('sex',axis=1,inplace=True)

df.loc[df.provider=="category 0",'provider0']=1
df.loc[df.provider!="category 0",'provider0']=0
df.loc[df.provider=="category 1",'provider1']=1
df.loc[df.provider!="category 1",'provider1']=0
df.loc[df.provider=="category 2",'provider2']=1
df.loc[df.provider!="category 2",'provider2']=0
df.drop('provider',axis=1,inplace=True)

df.loc[df.level=="category 0",'level0']=1
df.loc[df.level!="category 0",'level0']=0
df.loc[df.level=="category 1",'level1']=1
df.loc[df.level!="category 1",'level1']=0
df.loc[df.level=="category 2",'level2']=1
df.loc[df.level!="category 2",'level2']=0
df.drop('level',axis=1,inplace=True)

df.loc[df.verified=="category 0",'verified0']=1
df.loc[df.verified!="category 0",'verified0']=0
df.loc[df.verified=="category 1",'verified1']=1
df.loc[df.verified!="category 1",'verified1']=0
df.drop('verified',axis=1,inplace=True)

df.loc[df.regist_type=="category 0",'regist_type0']=1
df.loc[df.regist_type!="category 0",'regist_type0']=0
df.loc[df.regist_type=="category 1",'regist_type1']=1
df.loc[df.regist_type!="category 1",'regist_type1']=0
df.loc[df.regist_type=="category 2",'regist_type2']=1
df.loc[df.regist_type!="category 2",'regist_type2']=0
df.loc[df.regist_type=="category 3",'regist_type3']=1
df.loc[df.regist_type!="category 3",'regist_type3']=0
df.loc[df.regist_type=="category 4",'regist_type4']=1
df.loc[df.regist_type!="category 4",'regist_type4']=0
df.loc[df.regist_type=="category 5",'regist_type5']=1
df.loc[df.regist_type!="category 5",'regist_type5']=0
df.loc[df.regist_type=="category 6",'regist_type6']=1
df.loc[df.regist_type!="category 6",'regist_type6']=0
df.loc[df.regist_type=="category 7",'regist_type7']=1
df.loc[df.regist_type!="category 7",'regist_type7']=0
df.drop('regist_type',axis=1,inplace=True)

df.loc[df.agreement1=="category 0",'agreement10']=1
df.loc[df.agreement1!="category 0",'agreement10']=0
df.loc[df.agreement1=="category 1",'agreement11']=1
df.loc[df.agreement1!="category 1",'agreement11']=0
df.drop('agreement1',axis=1,inplace=True)

df.loc[df.agreement2=="category 0",'agreement20']=1
df.loc[df.agreement2!="category 0",'agreement20']=0
df.loc[df.agreement2=="category 1",'agreement21']=1
df.loc[df.agreement2!="category 1",'agreement21']=0
df.drop('agreement2',axis=1,inplace=True)

df.loc[df.agreement3=="category 0",'agreement30']=1
df.loc[df.agreement3!="category 0",'agreement30']=0
df.loc[df.agreement3=="category 1",'agreement31']=1
df.loc[df.agreement3!="category 1",'agreement31']=0
df.drop('agreement3',axis=1,inplace=True)

df.loc[df.agreement4=="category 0",'agreement40']=1
df.loc[df.agreement4!="category 0",'agreement40']=0
df.loc[df.agreement4=="category 1",'agreement41']=1
df.loc[df.agreement4!="category 1",'agreement41']=0
df.drop('agreement4',axis=1,inplace=True)

df.loc[df.service3=="category 0",'service30']=1
df.loc[df.service3!="category 0",'service30']=0
df.loc[df.service3=="category 1",'service31']=1
df.loc[df.service3!="category 1",'service31']=0
df.drop('service3',axis=1,inplace=True)

df.loc[df.service3_level=="category 0",'service3_level0']=1
df.loc[df.service3_level!="category 0",'service3_level0']=0
df.loc[df.service3_level=="category 1",'service3_level1']=1
df.loc[df.service3_level!="category 1",'service3_level1']=0
df.loc[df.service3_level=="category 2",'service3_level2']=1
df.loc[df.service3_level!="category 2",'service3_level2']=0
df.loc[df.service3_level=="category 3",'service3_level3']=1
df.loc[df.service3_level!="category 3",'service3_level3']=0
df.drop('service3_level',axis=1,inplace=True)

df.drop('province',axis=1,inplace=True)
df.drop('city',axis=1,inplace=True)

# %%
df['balance']=df.balance.str.extract('(\d+)').astype('float')
df['balance_avg']=df.balance_avg.str.extract('(\d+)').astype('float')
df['balance1']=df.balance1.str.extract('(\d+)').astype('float')
df['balance1_avg']=df.balance1_avg.str.extract('(\d+)').astype('float')
df['balance2']=df.balance2.str.extract('(\d+)').astype('float')
df['balance2_avg']=df.balance2_avg.str.extract('(\d+)').astype('float')
df['product1_amount']=df.product1_amount.str.extract('(\d+)').astype('float')
df['product2_amount']=df.product2_amount.str.extract('(\d+)').astype('float')
df['product3_amount']=df.product3_amount.str.extract('(\d+)').astype('float')
df['product4_amount']=df.product4_amount.str.extract('(\d+)').astype('float')
df['product5_amount']=df.product5_amount.str.extract('(\d+)').astype('float')
df['product6_amount']=df.product6_amount.str.extract('(\d+)').astype('float')

# %%
df.fillna(0, inplace = True)

# %%
df
# Out:
#               age  using_time  card_a_cnt  card_b_cnt  card_c_cnt  op1_cnt  \
# user
# Test_02230  24914       24735       24743       24725       24725    24712
# Test_21691  24920       24725       24725       24719       24712    24712
# Test_31857  24877       24722       24725       24712       24719    24719
# Test_13647  24914       24733       24719       24719       24706    24755
# Test_44427  24895       24713       24719       24712       24712    24712
# ...           ...         ...         ...         ...         ...      ...
# Test_27066  24938       24707       24712       24712       24706    24725
# Test_27848  24986       24737       24712       24712       24706    24712
# Test_24860  24920       24717       24719       24712       24712    24737
# Test_10406  24956       24707       24712       24712       24706    24706
# Test_29649  24840       24732       24719       24719       24706    24712
#
# ...

# %%
# df.drop('province',axis=1,inplace=True)
# df.drop('city',axis=1,inplace=True)

df.to_csv("test_proc.csv")

# %%
df = pd.read_csv(r"D:\2021\rc\train_proc.csv", encoding='gbk', index_col=0).reset_index(drop=True)

# %%
def meanX(dataX):
    return np.mean(dataX,axis=0)#axis=0表示依照列来求均值。假设输入list,则axis=1
average = meanX(df[1:])
average
# Out:
# age                24911.143177
# using_time         24722.632075
# card_a_cnt         24715.675208
# card_b_cnt         24714.451176
# card_c_cnt         24707.436062
#                        ...
# service3_level1        0.018939
# service3_level2        0.017446
# service3_level3        0.007153
# sex0                   0.771240
# sex1                   0.224437
# Length: 64, dtype: float64

# %%
average.to_csv('avg.csv')

# %%
m, n = np.shape(df)
m,n
# Out:
# (32157, 64)

# %%
print(df.info())
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 32157 entries, Train_30437 to Train_29317
# Data columns (total 65 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   label              32157 non-null  int64
#  1   age                32157 non-null  int64
#  2   using_time         32157 non-null  int64
#  3   card_a_cnt         32157 non-null  int64
#  4   card_b_cnt         32157 non-null  int64
#  5   card_c_cnt         32157 non-null  int64
#  6   op1_cnt            32157 non-null  int64
#  7   op2_cnt            32157 non-null  int64
#  8   card_d_cnt         32157 non-null  int64
#  9   agreement_total    32157 non-null  int64
#  10  service1_cnt       32157 non-null  int64
#  11  service1_amt       32157 non-null  int64
#  12  service2_cnt       32157 non-null  int64
#  13  acc_count          32157 non-null  int64
#  14  login_cnt_period1  32157 non-null  int64
#  15  login_cnt_period2  32157 non-null  int64
# ...

# %%
from sklearn import preprocessing
z_scaler= preprocessing.StandardScaler()
# 用 StandardScaler 对象对数据进行标准化处理
z_data = z_scaler.fit_transform(df)

# %%
z_data
# Out:
# array([[-0.57020426, -1.11474955,  0.57131901, ..., -0.13893854,
#         -0.13324944, -0.08487599],
#        [ 1.75375751, -0.60164654, -1.31282254, ..., -0.13893854,
#         -0.13324944, -0.08487599],
#        [-0.57020426,  0.29628373,  1.10964516, ..., -0.13893854,
#         -0.13324944, -0.08487599],
#        ...,
#        [-0.57020426, -0.34509503,  0.03299285, ..., -0.13893854,
#         -0.13324944, -0.08487599],
#        [-0.57020426,  0.83076604, -0.86421741, ..., -0.13893854,
#         -0.13324944, -0.08487599],
#        [-0.57020426, -1.24302531, -1.13338048, ..., -0.13893854,
#         -0.13324944, -0.08487599]])

# %%
data_adjust = []
avgs = np.tile(average, (m, 1))
avgs
# Out:
# array([[2.49111432e+04, 2.47226321e+04, 2.47156752e+04, ...,
#         7.15263092e-03, 7.71240204e-01, 2.24437119e-01],
#        [2.49111432e+04, 2.47226321e+04, 2.47156752e+04, ...,
#         7.15263092e-03, 7.71240204e-01, 2.24437119e-01],
#        [2.49111432e+04, 2.47226321e+04, 2.47156752e+04, ...,
#         7.15263092e-03, 7.71240204e-01, 2.24437119e-01],
#        ...,
#        [2.49111432e+04, 2.47226321e+04, 2.47156752e+04, ...,
#         7.15263092e-03, 7.71240204e-01, 2.24437119e-01],
#        [2.49111432e+04, 2.47226321e+04, 2.47156752e+04, ...,
#         7.15263092e-03, 7.71240204e-01, 2.24437119e-01],
#        [2.49111432e+04, 2.47226321e+04, 2.47156752e+04, ...,
#         7.15263092e-03, 7.71240204e-01, 2.24437119e-01]])

# %%
df.std()
# Out:
# age                46.774960
# using_time         11.145833
# card_a_cnt          7.236763
# card_b_cnt          5.220396
# card_c_cnt          4.367913
#                      ...
# service3_level1     0.136309
# service3_level2     0.130927
# service3_level3     0.084270
# sex0                0.420036
# sex1                0.417213
# Length: 64, dtype: float64

# %%
data_adjust = df - avgs
data_adjust
# Out:
#              age  using_time  card_a_cnt  card_b_cnt  card_c_cnt    op1_cnt  \
# 0     -52.143177    6.367925   -3.675208   -2.451176   -1.436062  -7.887641
# 1     -28.143177  -14.632075   -3.675208   -2.451176   -1.436062  -7.887641
# 2      13.856823   12.367925   -3.675208   -2.451176   -1.436062   5.112359
# 3      19.856823   -1.632075   -3.675208   -2.451176   -1.436062  -0.887641
# 4     -16.143177    3.367925   -3.675208   -2.451176   -1.436062  -0.887641
# ...          ...         ...         ...         ...         ...        ...
# 32152 -10.143177   19.367925    3.324792   -2.451176   11.563938  35.112359
# 32153 -10.143177  -10.632075   -3.675208   -2.451176   -1.436062  -0.887641
# 32154 -16.143177    0.367925    9.324792    4.548824    4.563938   5.112359
# 32155  38.856823   -9.632075   -3.675208   -2.451176   -1.436062 -13.887641
# 32156 -58.143177  -12.632075   -3.675208   -2.451176   -1.436062  -0.887641
#
# ...

# %%
covX = np.cov(data_adjust.T)   #计算协方差矩阵
covX
# Out:
# array([[ 1.85163571e-01, -1.76280858e+00, -5.28132643e-01, ...,
#         -1.75496029e-03,  1.27770451e-02, -1.36445392e-02],
#        [-1.76280858e+00,  2.18789693e+03,  1.06010073e+02, ...,
#          3.47165140e-01, -3.58866706e-01,  1.24562738e+00],
#        [-5.28132643e-01,  1.06010073e+02,  1.24229588e+02, ...,
#          1.26899404e-01, -1.99962696e-01,  2.28631870e-01],
#        ...,
#        [-1.75496029e-03,  3.47165140e-01,  1.26899404e-01, ...,
#          7.10147239e-03, -3.09077258e-03,  3.12169013e-03],
#        [ 1.27770451e-02, -3.58866706e-01, -1.99962696e-01, ...,
#         -3.09077258e-03,  1.76430379e-01, -1.73096526e-01],
#        [-1.36445392e-02,  1.24562738e+00,  2.28631870e-01, ...,
#          3.12169013e-03, -1.73096526e-01,  1.74066665e-01]])

# %%
featValue, featVec=  np.linalg.eig(covX)  #求解协方差矩阵的特征值和特征向量
featValue, featVec
# Out:
# (array([ 4.50898034e+07+0.00000000e+00j,  1.40998405e+07+0.00000000e+00j,
#          4.63138760e+05+0.00000000e+00j,  8.78406131e+03+0.00000000e+00j,
#          2.17146596e+03+0.00000000e+00j,  1.11171780e+03+0.00000000e+00j,
#          7.03919570e+02+0.00000000e+00j,  5.22921686e+02+0.00000000e+00j,
#          2.87815370e+02+0.00000000e+00j,  1.53434411e+02+0.00000000e+00j,
#          1.13436710e+02+0.00000000e+00j,  1.02362330e+02+0.00000000e+00j,
#          8.68958792e+01+0.00000000e+00j,  5.83985680e+01+0.00000000e+00j,
#          5.55293652e+01+0.00000000e+00j,  2.88142406e+01+0.00000000e+00j,
#          2.35739195e+01+0.00000000e+00j,  1.64552223e+01+0.00000000e+00j,
#          1.28042458e+01+0.00000000e+00j,  6.45880067e+00+0.00000000e+00j,
#          4.59586180e+00+0.00000000e+00j,  3.69626477e+00+0.00000000e+00j,
#          3.10469357e+00+0.00000000e+00j,  2.12995267e+00+0.00000000e+00j,
#          1.21247320e+00+0.00000000e+00j,  8.40237530e-01+0.00000000e+00j,
# ...

# %%
featValue = sorted(featValue)[::-1]
featValue
# Out:
# [(45089803.354146995+0j),
#  (14099840.52316391+0j),
#  (463138.7595677222+0j),
#  (8784.061312422922+0j),
#  (2171.465957737058+0j),
#  (1111.7178033392413+0j),
#  (703.9195703280811+0j),
#  (522.9216860281315+0j),
#  (287.81537042506284+0j),
#  (153.43441113733553+0j),
#  (113.43671000422208+0j),
#  (102.36233022851657+0j),
#  (86.89587923750447+0j),
#  (58.39856795852966+0j),
#  (55.52936522171188+0j),
#  (28.814240550192412+0j),
#  (23.57391946598019+0j),
#  (16.455222286492997+0j),
#  (12.804245833051894+0j),
#  (6.458800669802442+0j),
#  (4.59586179956999+0j),
#  (3.6962647655026233+0j),
#  (3.1046935675697966+0j),
#  (2.1299526738121393+0j),
#  (1.2124732034043542+0j),
#  (0.8402375295852145+0j),
#  (0.6616601159836227+0j),
#  (0.41413520171417595+0j),
#  (0.323098376520023+0j),
#  (0.27901194827504355+0j),
#  (0.25981769988315917+0j),
#  (0.23399903916897655+0j),
#  (0.19507999184251562+0j),
#  (0.17506795562546745+0j),
#  (0.16753628665572054+0j),
# ...

# %%
gx = featValue/np.sum(featValue)
gx
# Out:
# array([ 7.55690280e-01+0.00000000e+00j,  2.36308691e-01+0.00000000e+00j,
#         7.76205334e-03+0.00000000e+00j,  1.47217980e-04+0.00000000e+00j,
#         3.63930555e-05+0.00000000e+00j,  1.86320249e-05+0.00000000e+00j,
#         1.17974606e-05+0.00000000e+00j,  8.76399553e-06+0.00000000e+00j,
#         4.82369098e-06+0.00000000e+00j,  2.57151029e-06+0.00000000e+00j,
#         1.90116196e-06+0.00000000e+00j,  1.71555900e-06+0.00000000e+00j,
#         1.45634637e-06+0.00000000e+00j,  9.78740799e-07+0.00000000e+00j,
#         9.30653904e-07+0.00000000e+00j,  4.82917198e-07+0.00000000e+00j,
#         3.95091140e-07+0.00000000e+00j,  2.75784115e-07+0.00000000e+00j,
#         2.14594950e-07+0.00000000e+00j,  1.08247376e-07+0.00000000e+00j,
#         7.70251328e-08+0.00000000e+00j,  6.19481822e-08+0.00000000e+00j,
#         5.20336434e-08+0.00000000e+00j,  3.56973065e-08+0.00000000e+00j,
#         2.03206523e-08+0.00000000e+00j,  1.40821047e-08+0.00000000e+00j,
# ...

# %%
lg = np.cumsum(gx)
lg
# Out:
# array([0.75569028+0.00000000e+00j, 0.99199897+0.00000000e+00j,
#        0.99976102+0.00000000e+00j, 0.99990824+0.00000000e+00j,
#        0.99994464+0.00000000e+00j, 0.99996327+0.00000000e+00j,
#        0.99997507+0.00000000e+00j, 0.99998383+0.00000000e+00j,
#        0.99998865+0.00000000e+00j, 0.99999122+0.00000000e+00j,
#        0.99999313+0.00000000e+00j, 0.99999484+0.00000000e+00j,
#        0.9999963 +0.00000000e+00j, 0.99999728+0.00000000e+00j,
#        0.99999821+0.00000000e+00j, 0.99999869+0.00000000e+00j,
#        0.99999908+0.00000000e+00j, 0.99999936+0.00000000e+00j,
#        0.99999958+0.00000000e+00j, 0.99999968+0.00000000e+00j,
#        0.99999976+0.00000000e+00j, 0.99999982+0.00000000e+00j,
#        0.99999987+0.00000000e+00j, 0.99999991+0.00000000e+00j,
#        0.99999993+0.00000000e+00j, 0.99999994+0.00000000e+00j,
#        0.99999996+0.00000000e+00j, 0.99999996+0.00000000e+00j,
#        0.99999997+0.00000000e+00j, 0.99999997+0.00000000e+00j,
# ...

# %%
k=[i for i in range(len(lg)) if lg[i]<0.85]
k = list(k)
k
# Out:
# [0]

# %%
selectVec = np.matrix(featVec.T[index[10]]).T
selectVec
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3636/674375419.py in <module>
# ----> 1 selectVec = np.matrix(featVec.T[index[10]]).T
#       2 selectVec
#
# NameError: name 'index' is not defined

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=n)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10296/1101761988.py in <module>
# ----> 1 pca = PCA(n_components=n)
#       2 print(pca.explained_variance_ratio_)
#
# NameError: name 'PCA' is not defined

# %%
pca.fit(data_adjust)

print(pca.explained_variance_ratio_)  
# [0.98318212 0.00850037 0.00831751]
print(pca.explained_variance_)  
# [3.78521638 0.03272613 0.03202212]
# Out:
# [7.55690280e-01 2.36308691e-01 7.76205334e-03 1.47217980e-04
#  3.63930555e-05 1.86320249e-05 1.17974606e-05 8.76399553e-06
#  4.82369098e-06 2.57151029e-06 1.90116196e-06 1.71555900e-06
#  1.45634637e-06 9.78740799e-07 9.30653904e-07 4.82917198e-07
#  3.95091140e-07 2.75784115e-07 2.14594950e-07 1.08247376e-07
#  7.70251328e-08 6.19481822e-08 5.20336434e-08 3.56973065e-08
#  2.03206523e-08 1.40821047e-08 1.10892060e-08 6.94076982e-09
#  5.41502256e-09 4.67614852e-09 4.35445923e-09 3.92174696e-09
#  3.26947653e-09 2.93408138e-09 2.80785308e-09 1.83767255e-09
#  1.54232381e-09 1.17161097e-09 1.08325915e-09 9.88163485e-10
#  9.72621107e-10 7.15474284e-10 5.89464414e-10 3.95998248e-10
#  2.84593304e-10 1.32298994e-10 1.14773121e-10 6.60477226e-11
#  5.84510046e-11 5.08379272e-11 2.69610883e-11 6.21495029e-12
#  3.07545809e-12 6.89025248e-13 5.20482368e-13 7.13465960e-33
#  7.13465960e-33 7.13465960e-33 7.13465960e-33 7.13465960e-33
# ...

# %%
# linear regression feature importance
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot
# define dataset
X=np.array(z_data[:,1:])
y=np.array(df.values[:,0].astype("int"))
# define the model
model = LinearRegression()
# fit the model
model.fit(X, y)
# get importance
importance = model.coef_
# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 7.30204
# Feature: 1, Score: 0.71192
# Feature: 2, Score: -0.95441
# Feature: 3, Score: 2.80883
# Feature: 4, Score: 3.77613
# Feature: 5, Score: 0.84481
# Feature: 6, Score: 0.20117
# Feature: 7, Score: -7.08875
# Feature: 8, Score: 1.06986
# Feature: 9, Score: 0.62219
# Feature: 10, Score: 0.26927
# Feature: 11, Score: -1.76062
# Feature: 12, Score: 0.21309
# Feature: 13, Score: 0.21010
# Feature: 14, Score: -3.11809
# Feature: 15, Score: 4.29841
# Feature: 16, Score: 3.44072
# Feature: 17, Score: -0.01094
# Feature: 18, Score: 3.24986
# Feature: 19, Score: 1.55817
# Feature: 20, Score: -0.69179
# Feature: 21, Score: 2.10574
# Feature: 22, Score: -0.62922
# Feature: 23, Score: -0.55500
# Feature: 24, Score: 0.54233
# Feature: 25, Score: 0.69578
# Feature: 26, Score: 1.08077
# Feature: 27, Score: 0.32179
# Feature: 28, Score: 2.24709
# Feature: 29, Score: -6.28001
# Feature: 30, Score: 4.45418
# Feature: 31, Score: -64931551093252.90625
# ...

# %%
# logistic regression for feature importance
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot
# define the model
model = LogisticRegression()
# fit the model
model.fit(X, y)
# get importance
importance = model.coef_[0]
# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# c:\users\liu-yuxi\appdata\local\programs\python\python38\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Feature: 0, Score: 0.04446
# Feature: 1, Score: 0.04012
# Feature: 2, Score: 0.03846
# Feature: 3, Score: 0.01310
# Feature: 4, Score: 0.00522
# Feature: 5, Score: 0.12398
# Feature: 6, Score: -0.03271
# Feature: 7, Score: 0.21031
# Feature: 8, Score: 0.03676
# Feature: 9, Score: 0.04037
# Feature: 10, Score: 0.03264
# Feature: 11, Score: -0.72240
# Feature: 12, Score: -0.00424
# Feature: 13, Score: -0.00479
# ...

# %%
# decision tree for feature importance on a classification problem
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier
from matplotlib import pyplot
# define the model
model = DecisionTreeClassifier()
# fit the model
model.fit(X, y)
# get importance
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 0.07018
# Feature: 1, Score: 0.01669
# Feature: 2, Score: 0.01745
# Feature: 3, Score: 0.00573
# Feature: 4, Score: 0.03814
# Feature: 5, Score: 0.02228
# Feature: 6, Score: 0.00653
# Feature: 7, Score: 0.05076
# Feature: 8, Score: 0.00090
# Feature: 9, Score: 0.00161
# Feature: 10, Score: 0.00112
# Feature: 11, Score: 0.06133
# Feature: 12, Score: 0.08393
# Feature: 13, Score: 0.06950
# Feature: 14, Score: 0.05537
# Feature: 15, Score: 0.05102
# Feature: 16, Score: 0.05028
# Feature: 17, Score: 0.03484
# Feature: 18, Score: 0.04720
# Feature: 19, Score: 0.02263
# Feature: 20, Score: 0.02654
# Feature: 21, Score: 0.03654
# Feature: 22, Score: 0.01496
# Feature: 23, Score: 0.00819
# Feature: 24, Score: 0.02012
# Feature: 25, Score: 0.00179
# Feature: 26, Score: 0.00043
# Feature: 27, Score: 0.00030
# Feature: 28, Score: 0.02127
# Feature: 29, Score: 0.01817
# Feature: 30, Score: 0.01430
# Feature: 31, Score: 0.00333
# Feature: 32, Score: 0.00171
# ...

# %%
# decision tree for feature importance on a classification problem
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier
from matplotlib import pyplot
# define the model
model = DecisionTreeClassifier()
# fit the model
model.fit(X, y)
# get importance
importance = model.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 0.06996
# Feature: 1, Score: 0.01699
# Feature: 2, Score: 0.01781
# Feature: 3, Score: 0.00508
# Feature: 4, Score: 0.03860
# Feature: 5, Score: 0.02316
# Feature: 6, Score: 0.00636
# Feature: 7, Score: 0.05080
# Feature: 8, Score: 0.00082
# Feature: 9, Score: 0.00159
# Feature: 10, Score: 0.00058
# Feature: 11, Score: 0.06165
# Feature: 12, Score: 0.08187
# Feature: 13, Score: 0.06792
# Feature: 14, Score: 0.05824
# Feature: 15, Score: 0.04949
# Feature: 16, Score: 0.05225
# Feature: 17, Score: 0.03410
# Feature: 18, Score: 0.04615
# Feature: 19, Score: 0.02318
# Feature: 20, Score: 0.02637
# Feature: 21, Score: 0.03637
# Feature: 22, Score: 0.01511
# Feature: 23, Score: 0.00857
# Feature: 24, Score: 0.02040
# Feature: 25, Score: 0.00162
# Feature: 26, Score: 0.00054
# Feature: 27, Score: 0.00009
# Feature: 28, Score: 0.02174
# Feature: 29, Score: 0.01642
# Feature: 30, Score: 0.01505
# Feature: 31, Score: 0.00378
# Feature: 32, Score: 0.00195
# ...
